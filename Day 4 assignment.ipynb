# %% [markdown]
# # Question 1

# %%
opening_the_file = open('Assignment example.txt', 'w')
opening_the_file.write(' I Love LetsUpgrade ')
opening_the_file.close()

# %%
opening_the_file = open('Assignment example.txt', 'r+')
print(opening_the_file.read())
opening_the_file.write(' Python is the powerful language ')
opening_the_file.close()
# Out:
#  I Love LetsUpgrade  Python is the powerful language

# %% [markdown]
# # Question 2

# %%
def factorial(n): 
       
    if n == 0: 
        return 1
      
    return n * factorial(n-1) 
   
num = 5; 
print("Factorial of", num, "is", 
factorial(num))
# Out:
# Factorial of 5 is 120
